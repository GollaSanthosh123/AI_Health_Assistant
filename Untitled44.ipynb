# %% [markdown]
# <a href="https://colab.research.google.com/github/GollaSanthosh123/AI_Health_Assistant/blob/main/Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data={'marks':[90,90,78,31,31],
     'st_hrs':[10,12,7,5,2]}
df=pd.DataFrame(data)

# %%
df['marks'].describe()
# Out:
# count     5.000000
# mean     64.000000
# std      30.520485
# min      31.000000
# 25%      31.000000
# 50%      78.000000
# 75%      90.000000
# max      90.000000
# Name: marks, dtype: float64

# %%
df['marks'].corr(df['st_hrs'])
# Out:
# np.float64(0.9075347702584994)

# %%
df['marks'].var()
# Out:
# 931.5

# %%
df['marks'].mode()
# Out:
# 0    31
# 1    90
# Name: marks, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='marks',y='st_hrs',data=df)
plt.show()
